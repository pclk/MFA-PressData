# %% [markdown]
# # Introduction
# This notebook will:
# 1. Scrape and clean all press statements from last 3 years (ending from 13 March 2024)
# 2. Chunk the documents into passages
# 3. Load them into our Elasticsearch Docker container
# 4. Test out some queries.
#
# The next step will be the LLM testing notebook, where we will use the loaded Elasticsearch Docker container to do RAG.

# %% [markdown]
# #pip installs

# %%
# %pip install elasticsearch pandas beautifulsoup4 langchain tiktoken
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting elasticsearch
#   Downloading elasticsearch-8.13.1-py3-none-any.whl.metadata (6.5 kB)
# Collecting pandas
#   Downloading pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting langchain
#   Downloading langchain-0.1.20-py3-none-any.whl.metadata (13 kB)
# Collecting tiktoken
#   Using cached tiktoken-0.6.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Collecting elastic-transport<9,>=8.13 (from elasticsearch)
#   Downloading elastic_transport-8.13.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\intern-3ct2\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4)
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting PyYAML>=5.3 (from langchain)
#   Downloading PyYAML-6.0.1-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading SQLAlchemy-2.0.30-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Downloading aiohttp-3.9.5-cp312-cp312-win_amd64.whl.metadata (7.7 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.6.6-py3-none-any.whl.metadata (25 kB)
# Collecting langchain-community<0.1,>=0.0.38 (from langchain)
#   Downloading langchain_community-0.0.38-py3-none-any.whl.metadata (8.7 kB)
# Collecting langchain-core<0.2.0,>=0.1.52 (from langchain)
#   Downloading langchain_core-0.1.52-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain)
#   Using cached langchain_text_splitters-0.0.1-py3-none-any.whl.metadata (2.0 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.57-py3-none-any.whl.metadata (13 kB)
# Collecting pydantic<3,>=1 (from langchain)
#   Downloading pydantic-2.7.1-py3-none-any.whl.metadata (107 kB)
#      ---------------------------------------- 0.0/107.3 kB ? eta -:--:--
#      -------------------------------------- 107.3/107.3 kB 6.5 MB/s eta 0:00:00
# Collecting requests<3,>=2 (from langchain)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain)
#   Downloading tenacity-8.3.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting regex>=2022.1.18 (from tiktoken)
#   Downloading regex-2024.5.10-cp312-cp312-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ---------------------------------------- 42.0/42.0 kB ? eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\intern-3ct2\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached frozenlist-1.4.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached multidict-6.0.5-cp312-cp312-win_amd64.whl.metadata (4.3 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached yarl-1.9.4-cp312-cp312-win_amd64.whl.metadata (32 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading marshmallow-3.21.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: urllib3<3,>=1.26.2 in c:\users\intern-3ct2\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from elastic-transport<9,>=8.13->elasticsearch) (2.2.1)
# Requirement already satisfied: certifi in c:\users\intern-3ct2\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from elastic-transport<9,>=8.13->elasticsearch) (2024.2.2)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.2.0,>=0.1.52->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2.0,>=0.1.52->langchain)
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.3-cp312-none-win_amd64.whl.metadata (50 kB)
#      ---------------------------------------- 0.0/50.9 kB ? eta -:--:--
#      ---------------------------------------- 50.9/50.9 kB ? eta 0:00:00
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1->langchain)
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.18.2 (from pydantic<3,>=1->langchain)
#   Downloading pydantic_core-2.18.2-cp312-none-win_amd64.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\intern-3ct2\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=1->langchain) (4.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\intern-3ct2\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2->langchain)
#   Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\intern-3ct2\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests<3,>=2->langchain) (3.7)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Using cached greenlet-3.0.3-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.52->langchain)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading elasticsearch-8.13.1-py3-none-any.whl (477 kB)
#    ---------------------------------------- 0.0/477.5 kB ? eta -:--:--
#    -------------------------- ------------- 317.4/477.5 kB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 477.5/477.5 kB 7.5 MB/s eta 0:00:00
# Downloading pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.6/11.5 MB 20.1 MB/s eta 0:00:01
#    --- ------------------------------------ 1.1/11.5 MB 14.0 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.6/11.5 MB 14.8 MB/s eta 0:00:01
#    ------- -------------------------------- 2.2/11.5 MB 13.7 MB/s eta 0:00:01
#    -------- ------------------------------- 2.6/11.5 MB 12.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.0/11.5 MB 12.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.3/11.5 MB 11.9 MB/s eta 0:00:01
#    ------------ --------------------------- 3.6/11.5 MB 11.1 MB/s eta 0:00:01
#    ------------- -------------------------- 3.8/11.5 MB 10.6 MB/s eta 0:00:01
#    -------------- ------------------------- 4.1/11.5 MB 9.6 MB/s eta 0:00:01
#    --------------- ------------------------ 4.4/11.5 MB 9.3 MB/s eta 0:00:01
#    --------------- ------------------------ 4.6/11.5 MB 8.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.7/11.5 MB 8.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.8/11.5 MB 8.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.1/11.5 MB 8.1 MB/s eta 0:00:01
#    ------------------ --------------------- 5.3/11.5 MB 7.8 MB/s eta 0:00:01
#    ------------------ --------------------- 5.5/11.5 MB 7.7 MB/s eta 0:00:01
#    ------------------- -------------------- 5.6/11.5 MB 7.5 MB/s eta 0:00:01
#    -------------------- ------------------- 5.8/11.5 MB 7.4 MB/s eta 0:00:01
#    -------------------- ------------------- 6.0/11.5 MB 7.3 MB/s eta 0:00:01
#    --------------------- ------------------ 6.2/11.5 MB 7.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.4/11.5 MB 7.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.6/11.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.6/11.5 MB 6.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.5 MB 6.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.8/11.5 MB 6.3 MB/s eta 0:00:01
#    ------------------------ --------------- 7.0/11.5 MB 6.2 MB/s eta 0:00:01
#    ------------------------ --------------- 7.2/11.5 MB 6.1 MB/s eta 0:00:01
#    ------------------------- -------------- 7.4/11.5 MB 6.1 MB/s eta 0:00:01
#    -------------------------- ------------- 7.7/11.5 MB 6.1 MB/s eta 0:00:01
#    --------------------------- ------------ 7.9/11.5 MB 6.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.2/11.5 MB 6.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.3/11.5 MB 6.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.5/11.5 MB 5.9 MB/s eta 0:00:01
#    ------------------------------ --------- 8.6/11.5 MB 5.9 MB/s eta 0:00:01
#    ------------------------------ --------- 8.9/11.5 MB 5.9 MB/s eta 0:00:01
#    ------------------------------- -------- 9.2/11.5 MB 5.9 MB/s eta 0:00:01
#    -------------------------------- ------- 9.4/11.5 MB 5.9 MB/s eta 0:00:01
#    --------------------------------- ------ 9.6/11.5 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.8/11.5 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.0/11.5 MB 5.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.3/11.5 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------ --- 10.4/11.5 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.5 MB 5.6 MB/s eta 0:00:01
#    -------------------------------------- - 10.9/11.5 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 11.1/11.5 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 5.2 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    ---------------------------------------- 147.9/147.9 kB 9.2 MB/s eta 0:00:00
# Downloading langchain-0.1.20-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    -------- ------------------------------- 0.2/1.0 MB 6.9 MB/s eta 0:00:01
#    ------------------- -------------------- 0.5/1.0 MB 6.3 MB/s eta 0:00:01
#    --------------------------------- ------ 0.8/1.0 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 6.4 MB/s eta 0:00:00
# Using cached tiktoken-0.6.0-cp312-cp312-win_amd64.whl (798 kB)
# Downloading aiohttp-3.9.5-cp312-cp312-win_amd64.whl (369 kB)
#    ---------------------------------------- 0.0/369.0 kB ? eta -:--:--
#    -------------------------------- ------- 297.0/369.0 kB 9.0 MB/s eta 0:00:01
#    ---------------------------------------- 369.0/369.0 kB 7.6 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.6-py3-none-any.whl (28 kB)
# Downloading elastic_transport-8.13.0-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.3 kB ? eta -:--:--
#    ---------------------------------------- 64.3/64.3 kB 3.4 MB/s eta 0:00:00
# Downloading langchain_community-0.0.38-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/2.0 MB 9.3 MB/s eta 0:00:01
#    -------------- ------------------------- 0.7/2.0 MB 9.1 MB/s eta 0:00:01
#    --------------------- ------------------ 1.1/2.0 MB 8.4 MB/s eta 0:00:01
#    --------------------------- ------------ 1.4/2.0 MB 7.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.8/2.0 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 7.6 MB/s eta 0:00:00
# Downloading langchain_core-0.1.52-py3-none-any.whl (302 kB)
#    ---------------------------------------- 0.0/302.9 kB ? eta -:--:--
#    ---------------------------------------- 302.9/302.9 kB 9.4 MB/s eta 0:00:00
# Using cached langchain_text_splitters-0.0.1-py3-none-any.whl (21 kB)
# Downloading langsmith-0.1.57-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.0 kB ? eta -:--:--
#    ---------------------------------------- 121.0/121.0 kB 6.9 MB/s eta 0:00:00
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Downloading pydantic-2.7.1-py3-none-any.whl (409 kB)
#    ---------------------------------------- 0.0/409.3 kB ? eta -:--:--
#    ----------------------- ---------------- 235.5/409.3 kB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 409.3/409.3 kB 6.3 MB/s eta 0:00:00
# Downloading pydantic_core-2.18.2-cp312-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.2/1.9 MB 7.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.5/1.9 MB 6.4 MB/s eta 0:00:01
#    -------------- ------------------------- 0.7/1.9 MB 6.3 MB/s eta 0:00:01
#    ------------------ --------------------- 0.9/1.9 MB 5.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.1/1.9 MB 5.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/1.9 MB 5.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.4/1.9 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.9 MB 5.2 MB/s eta 0:00:01
#    ------------------------------------- -- 1.8/1.9 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 4.9 MB/s eta 0:00:00
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ---------------------------------------- 0.0/505.5 kB ? eta -:--:--
#    ------------ --------------------------- 153.6/505.5 kB 3.1 MB/s eta 0:00:01
#    -------------------------- ------------- 337.9/505.5 kB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 505.5/505.5 kB 4.5 MB/s eta 0:00:00
# Downloading PyYAML-6.0.1-cp312-cp312-win_amd64.whl (138 kB)
#    ---------------------------------------- 0.0/138.7 kB ? eta -:--:--
#    ---------------------------------------- 138.7/138.7 kB 4.1 MB/s eta 0:00:00
# Downloading regex-2024.5.10-cp312-cp312-win_amd64.whl (268 kB)
#    ---------------------------------------- 0.0/268.5 kB ? eta -:--:--
#    --------------------------------- ------ 225.3/268.5 kB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 268.5/268.5 kB 4.2 MB/s eta 0:00:00
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#    ---------------------------------------- 62.6/62.6 kB 3.3 MB/s eta 0:00:00
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Downloading SQLAlchemy-2.0.30-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/2.1 MB 4.3 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.3/2.1 MB 3.8 MB/s eta 0:00:01
#    -------- ------------------------------- 0.5/2.1 MB 4.0 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.6/2.1 MB 4.0 MB/s eta 0:00:01
#    ------------- -------------------------- 0.7/2.1 MB 3.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.8/2.1 MB 3.8 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.1 MB 3.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.2/2.1 MB 3.7 MB/s eta 0:00:01
#    ------------------------- -------------- 1.3/2.1 MB 3.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.5/2.1 MB 3.9 MB/s eta 0:00:01
#    -------------------------------- ------- 1.7/2.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 2.0/2.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 4.0 MB/s eta 0:00:00
# Downloading tenacity-8.3.0-py3-none-any.whl (25 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
#    ---------------------------------------- 0.0/100.4 kB ? eta -:--:--
#    ---------------------------------------- 100.4/100.4 kB 6.0 MB/s eta 0:00:00
# Using cached frozenlist-1.4.1-cp312-cp312-win_amd64.whl (50 kB)
# Using cached greenlet-3.0.3-cp312-cp312-win_amd64.whl (293 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading marshmallow-3.21.2-py3-none-any.whl (49 kB)
#    ---------------------------------------- 0.0/49.3 kB ? eta -:--:--
#    ---------------------------------------- 49.3/49.3 kB ? eta 0:00:00
# Using cached multidict-6.0.5-cp312-cp312-win_amd64.whl (27 kB)
# Downloading orjson-3.10.3-cp312-none-win_amd64.whl (138 kB)
#    ---------------------------------------- 0.0/138.8 kB ? eta -:--:--
#    ---------------------------------------- 138.8/138.8 kB 4.0 MB/s eta 0:00:00
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached yarl-1.9.4-cp312-cp312-win_amd64.whl (76 kB)
# Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: pytz, tzdata, tenacity, soupsieve, regex, PyYAML, pydantic-core, packaging, orjson, numpy, mypy-extensions, multidict, jsonpointer, greenlet, frozenlist, elastic-transport, charset-normalizer, annotated-types, yarl, typing-inspect, SQLAlchemy, requests, pydantic, pandas, marshmallow, jsonpatch, elasticsearch, beautifulsoup4, aiosignal, tiktoken, langsmith, dataclasses-json, aiohttp, langchain-core, langchain-text-splitters, langchain-community, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed PyYAML-6.0.1 SQLAlchemy-2.0.30 aiohttp-3.9.5 aiosignal-1.3.1 annotated-types-0.6.0 beautifulsoup4-4.12.3 charset-normalizer-3.3.2 dataclasses-json-0.6.6 elastic-transport-8.13.0 elasticsearch-8.13.1 frozenlist-1.4.1 greenlet-3.0.3 jsonpatch-1.33 jsonpointer-2.4 langchain-0.1.20 langchain-community-0.0.38 langchain-core-0.1.52 langchain-text-splitters-0.0.1 langsmith-0.1.57 marshmallow-3.21.2 multidict-6.0.5 mypy-extensions-1.0.0 numpy-1.26.4 orjson-3.10.3 packaging-23.2 pandas-2.2.2 pydantic-2.7.1 pydantic-core-2.18.2 pytz-2024.1 regex-2024.5.10 requests-2.31.0 soupsieve-2.5 tenacity-8.3.0 tiktoken-0.6.0 typing-inspect-0.9.0 tzdata-2024.1 yarl-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #imports

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from bs4 import NavigableString
import time
import re
import datetime
from langchain.text_splitter import RecursiveCharacterTextSplitter
from elasticsearch import Elasticsearch, helpers
import json
import pickle

# %% [markdown]
# #Scraping and Cleaning MFA Press statements

# %%
def scrape(base_url, startdate, enddate):
    headers = {'User-Agent': 'Mozilla/5.0'}
    all_posts_info = []

    pages_scraped = 0
    start_time = time.time()

    # Scraping loop
    page = 1
    while True:
        url = f"{base_url}?keyword=&country=&startdate={startdate}&enddate={enddate}&topic=F5B66A618AEB4477A3E97996C9D05255&page={page}" # the value after topic represents Press Statements Only
        print(f"Scraping URL: {url}")
        response = requests.get(url, headers=headers)
        # time.sleep(1)

        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            statements = soup.select('body > div.off-canvas-wrapper > div > div > section > div.press-release > div > div > div.strip2')# web index

            if not statements:
                print(f"No more statements found. Exiting...")
                break

            for statement in statements:
                title_element = statement.select_one('div.sec2 > h3 > a')
                meta_element = statement.select_one('div.sec2 > p.strip2__labels') # the parent of 3 elements, datetime, type and country.
                date = meta_element.select_one('span.date').get_text(strip=True)
                countries = []
                for element in meta_element:
                    if isinstance(element, str):  # Skip any string elements, like newlines.
                        continue
                    if (element.get_text(strip=True) in ["Press Statements", "Spokeperson's Comments", "Transcripts", "Outcome Documents"]) or not (element.get_text(strip=True).isalpha()):  # Skip known labels.
                        continue  # Skip collecting details about its document type
                    countries.append(element.get_text(strip=True))
                country = ", ".join(countries)



                # time.sleep(1)
                statement_response = requests.get(title_element['href'], headers=headers)
                if statement_response.status_code == 429:
                    print(f"Rate limit hit, saving collected data and exiting...")
                    return all_posts_info

                statement_soup = BeautifulSoup(statement_response.text, 'html.parser')

                  # Select the content container
                content_container = statement_soup.select_one('body > div.off-canvas-wrapper > div > div > section > div.innerpage2 > div > div > div:nth-child(1)')

                # Assume 'content_container' is a BeautifulSoup object containing the parsed HTML of a content container.

                if content_container:
                    content_pieces = []
                    for paragraph in content_container.select('div, p'):
                        paragraph_text = ''
                        for elem in paragraph.descendants:
                            if isinstance(elem, NavigableString):
                                if elem and any(char.isalpha() or char in "()[]" for char in elem):
                                    # Append text with a space only if there's already text accumulated.
                                    paragraph_text += elem
                            elif elem.name == 'br':  # Check if the element is a line break
                                paragraph_text += ' '  # Add a space for a line break

                        # Collapse multiple whitespace into single spaces for the entire paragraph
                        paragraph_text = ' '.join(paragraph_text.split())

                        # Append the entire paragraph text to content pieces with a newline
                        if paragraph_text:  # Make sure not to append empty paragraphs
                            content_pieces.append(paragraph_text)

                    # Join all paragraphs with a newline
                    content = '\n'.join(content_pieces)

                    print(f"Page {page}: {date}, {country}, {len(content)} content length.")

                    # Add the post info including code length
                    all_posts_info.append({
                        'url': title_element['href'],
                        'title': title_element.get_text(strip=True),
                        'date': date,
                        'country': country,
                        'content': content
                    })

            pages_scraped += 1
            elapsed_time = time.time() - start_time
            avg_time_per_page = elapsed_time / pages_scraped

            # Since 'total_pages' is not available, we cannot calculate 'pages_left' and 'estimated_time_left' directly.
            # Instead, we will display the average time per page and the number of pages scraped so far.
            print(f"\nPage {page} scraped. Total pages scraped so far: {pages_scraped}. Average time per page: {avg_time_per_page:.2f} seconds.\n")
            page += 1

        elif response.status_code == 429:
            print(f"Rate limit hit, saving collected data and exiting...")
            return all_posts_info
        else:
            print(f"Error fetching page {page}, Status Code: {response.status_code}")
            return all_posts_info

    elapsed_time = time.time() - start_time
    print(f"\nScraping completed. {pages_scraped} pages scraped in {elapsed_time:.2f} seconds.\n")

    return all_posts_info

base_url = 'https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos'
#date: mm/dd/yyyy
data = scrape(base_url, '01/01/2021', '08/05/2024')
print(len(data), "statements collected.")
df = pd.DataFrame(data)
# Out:
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=1
# Page 1: 08 May 2024, 23:15, , 567 content length.
# Page 1: 08 May 2024, 23:02, , 1769 content length.
# Page 1: 08 May 2024, 19:44, , 2238 content length.
# Page 1: 08 May 2024, 19:40, , 2138 content length.
# Page 1: 08 May 2024, 19:35, Israel, 986 content length.
#
# Page 1 scraped. Total pages scraped so far: 1. Average time per page: 2.03 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=2
# Page 2: 07 May 2024, 21:16, , 1283 content length.
# Page 2: 07 May 2024, 20:02, Malaysia, 2404 content length.
# Page 2: 07 May 2024, 19:36, , 1499 content length.
# Page 2: 05 May 2024, 18:20, Malaysia, 1208 content length.
# Page 2: 05 May 2024, 18:11, Poland, 2047 content length.
#
# Page 2 scraped. Total pages scraped so far: 2. Average time per page: 2.40 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page
Average time per page: 2.59 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=19
# Page 19: 16 Jan 2024, 12:16, India, 1547 content length.
# Page 19: 12 Jan 2024, 23:53, Germany, 1702 content length.
# Page 19: 12 Jan 2024, 20:44, Jordan, 3388 content length.
# Page 19: 12 Jan 2024, 18:59, , 1134 content length.
# Page 19: 10 Jan 2024, 22:52, , 1719 content length.
#
# Page 19 scraped. Total pages scraped so far: 19. Average time per page: 2.59 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=20
# Page 20: 10 Jan 2024, 18:11, Malaysia, 1729 content length.
# Page 20: 10 Jan 2024, 11:52, Jordan, 1232 content length.
# Page 20: 09 Jan 2024, 19:41, Denmark, 2114 content length.
# Page 20: 09 Jan 2024, 18:04, China, 1678 content length.
# Page 20: 07 Jan 2024, 18:00, Thailand, 643 content length.
#
# Page 20 scraped. Total pages scraped so far: 20. Average time per page: 2.59 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=21
# Page 21: 07 Jan 2024, 10:08, Australia, 1362 content length.
# Page 21: 06 Jan 2024, 22:16, Portugal, 6563 content length.
# Page 21: 06 Jan 2024, 16:02, Iran, 896 content length.
# Page 21: 04 Jan 2024, 22:00, Kuwait, 1116 content length.
# Page 21: 04 Jan 2024, 17:05, Japan, 814 content length.
#
# Page 21 scraped. Total pages scraped so far: 21. Average time per page: 2.59 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=22
# Page 22: 03 Jan 2024, 17:50, Portugal, Denmark, 1414 content length.
# Page 22: 02 Jan 2024, 17:36, Japan, 1267 content length.
# Page 22: 21 Dec 2023, 14:07, , 625 content length.
# Page 22: 20 Dec 2023, 12:03, Egypt, 1133 content length.
# Page 22: 17 Dec 2023, 21:30, Kuwait, 1002 content length.
#
# Page 22 scraped. Total pages scraped so far: 22. Average time per page: 2.58 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=23
# Page 23: 16 Dec 2023, 14:30, Japan, 1717 content length.
# Page 23: 16 Dec 2023, 08:13, Israel, 4690 content length.
# Page 23: 14 Dec 2023, 17:35, Japan, 1026 content length.
# Page 23: 14 Dec 2023, 16:38, Oman, 2604 content length.
# Page 23: 13 Dec 2023, 20:04, , 20906 content length.
#
# Page 23 scraped. Total pages scraped so far: 23. Average time per page: 2.57 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=24
# Page 24: 13 Dec 2023, 17:34, Oman, 1593 content length.
# Page 24: 12 Dec 2023, 21:09, , 2978 content length.
# Page 24: 12 Dec 2023, 17:44, Egypt, Kuwait, Slovakia, 3665 content length.
# Page 24: 12 Dec 2023, 17:12, , 2686 content length.
# Page 24: 11 Dec 2023, 15:29, , 2772 content length.
#
# Page 24 scraped. Total pages scraped so far: 24. Average time per page: 2.58 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=25
# Page 25: 09 Dec 2023, 17:43, , 1298 content length.
# Page 25: 08 Dec 2023, 11:48, Argentina, Uruguay, Paraguay, 5112 content length.
# Page 25: 07 Dec 2023, 20:43, Laos, 4110 content length.
# Page 25: 07 Dec 2023, 17:53, China, 10896 content length.
# Page 25: 06 Dec 2023, 22:36, Philippines, 453 content length.
#
# Page 25 scraped. Total pages scraped so far: 25. Average time per page: 2.59 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=26
# Page 26: 05 Dec 2023, 17:47, Brazil, 1324 content length.
# Page 26: 05 Dec 2023, 14:33, China, 2686 content length.
# Page 26: 03 Dec 2023, 17:00, , 1089 content length.
# Page 26: 02 Dec 2023, 09:04, Brazil, 1490 content length.
# Page 26: 01 Dec 2023, 11:52, , 5235 content length.
#
# Page 26 scraped. Total pages scraped so far: 26. Average time per page: 2.59 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=27
# Page 27: 30 Nov 2023, 02:32, , 9288 content length.
# Page 27: 27 Nov 2023, 17:33, , 999 content length.
# Page 27: 25 Nov 2023, 16:55, , 693 content length.
# Page 27: 22 Nov 2023, 23:12, China, 1465 content length.
# Page 27: 22 Nov 2023, 23:07, Japan, 1273 content length.
#
# Page 27 scraped. Total pages scraped so far: 27. Average time per page: 2.59 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=28
# Page 28: 17 Nov 2023, 20:18, Vietnam, 3198 content length.
# Page 28: 17 Nov 2023, 12:07, , 5518 content length.
# Page 28: 17 Nov 2023, 07:19, Israel, 1103 content length.
# Page 28: 14 Nov 2023, 01:41, , 876 content length.
# Page 28: 13 Nov 2023, 18:43, , 1411 content length.
#
# Page 28 scraped. Total pages scraped so far: 28. Average time per page: 2.59 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=29
# Page 29: 11 Nov 2023, 18:37, , 2907 content length.
# Page 29: 11 Nov 2023, 18:05, , 10807 content length.
# Page 29: 09 Nov 2023, 09:55, Algeria, 3140 content length.
# Page 29: 09 Nov 2023, 09:11, , 1015 content length.
# Page 29: 08 Nov 2023, 23:05, , 1706 content length.
#
# Page 29 scraped. Total pages scraped so far: 29. Average time per page: 2.60 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=30
# Page 30: 08 Nov 2023, 20:15, Kosovo, 682 content length.
# Page 30: 08 Nov 2023, 19:02, China, 1944 content length.
# Page 30: 07 Nov 2023, 07:57, China, 1059 content length.
# Page 30: 06 Nov 2023, 18:11, Algeria, Egypt, 968 content length.
# Page 30: 05 Nov 2023, 18:11, Colombia, 1751 content length.
#
# Page 30 scraped. Total pages scraped so far: 30. Average time per page: 2.60 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=31
# Page 31: 04 Nov 2023, 17:06, , 809 content length.
# Page 31: 02 Nov 2023, 18:42, , 1281 content length.
# Page 31: 02 Nov 2023, 18:00, China, 2200 content length.
# Page 31: 31 Oct 2023, 20:06, Finland, Italy, Sweden, 4249 content length.
# Page 31: 31 Oct 2023, 18:51, Israel, Thailand, 2650 content length.
#
# Page 31 scraped. Total pages scraped so far: 31. Average time per page: 2.61 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=32
# Page 32: 31 Oct 2023, 17:49, China, 232 content length.
# Page 32: 29 Oct 2023, 18:08, Japan, 1022 content length.
# Page 32: 29 Oct 2023, 17:00, Malaysia, 2357 content length.
# Page 32: 28 Oct 2023, 14:30, China, 2107 content length.
# Page 32: 23 Oct 2023, 11:51, Finland, 4492 content length.
#
# Page 32 scraped. Total pages scraped so far: 32. Average time per page: 2.60 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=33
# Page 33: 22 Oct 2023, 18:24, , 6074 content length.
# Page 33: 20 Oct 2023, 23:23, Iceland, 6630 content length.
# Page 33: 18 Oct 2023, 23:25, , 3937 content length.
# Page 33: 18 Oct 2023, 22:12, , 2242 content length.
# Page 33: 18 Oct 2023, 18:52, , 1018 content length.
#
# Page 33 scraped. Total pages scraped so far: 33. Average time per page: 2.60 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=34
# Page 34: 18 Oct 2023, 14:36, Lebanon, 1294 content length.
# Page 34: 17 Oct 2023, 18:00, Iceland, 618 content length.
# Page 34: 17 Oct 2023, 13:00, , 2442 content length.
# Page 34: 15 Oct 2023, 16:06, , 1545 content length.
# Page 34: 15 Oct 2023, 07:06, , 3147 content length.
#
# Page 34 scraped. Total pages scraped so far: 34. Average time per page: 2.60 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page
Average time per page: 2.60 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=42
# Page 42: 29 Aug 2023, 18:48, Turkey, Qatar, 6665 content length.
# Page 42: 29 Aug 2023, 14:42, Botswana, Ghana, Mauritius, Mozambique, Rwanda, Uganda, 5173 content length.
# Page 42: 28 Aug 2023, 18:32, Vietnam, 7109 content length.
# Page 42: 28 Aug 2023, 17:20, Botswana, Ghana, Mauritius, Mozambique, Rwanda, Uganda, 1779 content length.
# Page 42: 26 Aug 2023, 17:00, Vietnam, 1721 content length.
#
# Page 42 scraped. Total pages scraped so far: 42. Average time per page: 2.60 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=43
# Page 43: 25 Aug 2023, 15:17, Qatar, 3842 content length.
# Page 43: 24 Aug 2023, 16:54, Qatar, 2920 content length.
# Page 43: 24 Aug 2023, 14:40, Thailand, 1515 content length.
# Page 43: 23 Aug 2023, 16:54, Qatar, 2251 content length.
# Page 43: 22 Aug 2023, 16:40, , 2280 content length.
#
# Page 43 scraped. Total pages scraped so far: 43. Average time per page: 2.59 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=44
# Page 44: 18 Aug 2023, 22:23, Thailand, 1407 content length.
# Page 44: 12 Aug 2023, 12:54, Indonesia, 3526 content length.
# Page 44: 11 Aug 2023, 18:54, China, 3382 content length.
# Page 44: 10 Aug 2023, 09:00, Indonesia, 938 content length.
# Page 44: 09 Aug 2023, 21:00, China, 639 content length.
#
# Page 44 scraped. Total pages scraped so far: 44. Average time per page: 2.59 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=45
# Page 45: 07 Aug 2023, 12:57, Cambodia, 9377 content length.
# Page 45: 01 Aug 2023, 22:26, , 2402 content length.
# Page 45: 28 Jul 2023, 16:17, Austria, 1420 content length.
# Page 45: 27 Jul 2023, 19:06, , 32603 content length.
# Page 45: 27 Jul 2023, 13:31, Finland, 7895 content length.
#
# Page 45 scraped. Total pages scraped so far: 45. Average time per page: 2.59 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=46
# Page 46: 25 Jul 2023, 20:18, Laos, Russia, 4032 content length.
# Page 46: 25 Jul 2023, 20:04, Austria, 577 content length.
# Page 46: 25 Jul 2023, 18:38, India, Israel, Turkmenistan, Uganda, 5037 content length.
# Page 46: 24 Jul 2023, 17:00, , 6835 content length.
# Page 46: 24 Jul 2023, 15:21, , 3031 content length.
#
# Page 46 scraped. Total pages scraped so far: 46. Average time per page: 2.59 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=47
# Page 47: 24 Jul 2023, 13:18, , 2207 content length.
# Page 47: 23 Jul 2023, 23:01, , 1850 content length.
# Page 47: 23 Jul 2023, 15:06, , 824 content length.
# Page 47: 22 Jul 2023, 17:07, , 734 content length.
# Page 47: 19 Jul 2023, 18:00, China, 3088 content length.
#
# Page 47 scraped. Total pages scraped so far: 47. Average time per page: 2.59 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=48
# Page 48: 18 Jul 2023, 16:10, Vietnam, 1813 content length.
# Page 48: 17 Jul 2023, 11:40, Vietnam, 919 content length.
# Page 48: 16 Jul 2023, 17:50, , 3211 content length.
# Page 48: 15 Jul 2023, 17:09, China, 1269 content length.
# Page 48: 14 Jul 2023, 20:36, , 627 content length.
#
# Page 48 scraped. Total pages scraped so far: 48. Average time per page: 2.59 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=49
# Page 49: 13 Jul 2023, 14:57, , 268 content length.
# Page 49: 12 Jul 2023, 21:17, China, 1894 content length.
# Page 49: 12 Jul 2023, 16:54, Indonesia, 1551 content length.
# Page 49: 11 Jul 2023, 02:04, Israel, 2538 content length.
# Page 49: 10 Jul 2023, 18:03, Indonesia, 1269 content length.
#
# Page 49 scraped. Total pages scraped so far: 49. Average time per page: 2.59 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=50
# Page 50: 09 Jul 2023, 18:00, Malaysia, 1439 content length.
# Page 50: 09 Jul 2023, 18:00, Indonesia, 740 content length.
# Page 50: 05 Jul 2023, 19:23, Myanmar, 2263 content length.
# Page 50: 04 Jul 2023, 21:10, China, 749 content length.
# Page 50: 03 Jul 2023, 20:04, Singapore, 6517 content length.
#
# Page 50 scraped. Total pages scraped so far: 50. Average time per page: 2.60 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=51
# Page 51: 01 Jul 2023, 19:07, , 1698 content length.
# Page 51: 01 Jul 2023, 18:00, Australia, 1207 content length.
# Page 51: 27 Jun 2023, 17:49, , 2433 content length.
# Page 51: 26 Jun 2023, 17:04, , 576 content length.
# Page 51: 25 Jun 2023, 21:29, Russia, 1100 content length.
#
# Page 51 scraped. Total pages scraped so far: 51. Average time per page: 2.61 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=52
# Page 52: 21 Jun 2023, 18:38, Qatar, 2704 content length.
# Page 52: 21 Jun 2023, 10:25, , 2040 content length.
# Page 52: 20 Jun 2023, 12:32, , 14424 content length.
# Page 52: 19 Jun 2023, 18:05, Qatar, 1304 content length.
# Page 52: 18 Jun 2023, 18:00, Austria, Hungary, 1869 content length.
#
# Page 52 scraped. Total pages scraped so far: 52. Average time per page: 2.60 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=53
# Page 53: 17 Jun 2023, 07:42, , 3940 content length.
# Page 53: 16 Jun 2023, 10:50, , 4263 content length.
# Page 53: 14 Jun 2023, 18:00, , 1096 content length.
# Page 53: 14 Jun 2023, 18:00, Philippines, 1951 content length.
# Page 53: 13 Jun 2023, 18:29, Philippines, 1427 content length.
#
# Page 53 scraped. Total pages scraped so far: 53. Average time per page: 2.61 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=54
# Page 54: 12 Jun 2023, 22:22, India, 10969 content length.
# Page 54: 11 Jun 2023, 07:44, India, 921 content length.
# Page 54: 09 Jun 2023, 20:05, Singapore, 22088 content length.
# Page 54: 08 Jun 2023, 17:08, , 6770 content length.
# Page 54: 06 Jun 2023, 17:53, Indonesia, 616 content length.
#
# Page 54 scraped. Total pages scraped so far: 54. Average time per page: 2.61 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=55
# Page 55: 05 Jun 2023, 20:00, Estonia, 869 content length.
# Page 55: 05 Jun 2023, 17:45, Indonesia, 1966 content length.
# Page 55: 04 Jun 2023, 12:42, India, 1096 content length.
# Page 55: 02 Jun 2023, 14:12, Australia, 18713 content length.
# Page 55: 01 Jun 2023, 18:10, Australia, 1146 content length.
#
# Page 55 scraped. Total pages scraped so far: 55. Average time per page: 2.62 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=56
# Page 56: 01 Jun 2023, 08:49, France, 996 content length.
# Page 56: 30 May 2023, 19:22, Japan, Philippines, 8676 content length.
# Page 56: 30 May 2023, 12:26, Turkey, 2120 content length.
# Page 56: 27 May 2023, 09:40, Poland, 790 content length.
# Page 56: 26 May 2023, 18:30, Japan, 1331 content length.
#
# Page 56 scraped. Total pages scraped so far: 56. Average time per page: 2.62 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=57
# Page 57: 24 May 2023, 19:05, Uzbekistan, 2736 content length.
# Page 57: 24 May 2023, 18:02, France, Poland, 819 content length.
# Page 57: 23 May 2023, 17:10, , 2089 content length.
# Page 57: 22 May 2023, 18:28, Kazakhstan, 2676 content length.
# Page 57: 20 May 2023, 18:25, Kazakhstan, Uzbekistan, 2097 content length.
#
# Page 57 scraped. Total pages scraped so far: 57. Average time per page: 2.62 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=58
# Page 58: 18 May 2023, 17:38, Kenya, 1557 content length.
# Page 58: 18 May 2023, 17:34, Vietnam, 2228 content length.
# Page 58: 16 May 2023, 23:29, China, 4237 content length.
# Page 58: 16 May 2023, 19:19, , 1618 content length.
# Page 58: 14 May 2023, 12:00, Sweden, 8371 content length.
#
# Page 58 scraped. Total pages scraped so far: 58. Average time per page: 2.62 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=59
# Page 59: 13 May 2023, 23:50, Bangladesh, 11892 content length.
# Page 59: 13 May 2023, 18:00, Kenya, 1729 content length.
# Page 59: 13 May 2023, 09:00, China, 1291 content length.
# Page 59: 11 May 2023, 18:00, Sweden, 957 content length.
# Page 59: 10 May 2023, 20:47, Sudan, 834 content length.
#
# Page 59 scraped. Total pages scraped so far: 59. Average time per page: 2.62 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=60
# Page 60: 10 May 2023, 17:30, , 826 content length.
# Page 60: 10 May 2023, 17:00, Bangladesh, 980 content length.
# Page 60: 09 May 2023, 18:21, Myanmar, 1630 content length.
# Page 60: 09 May 2023, 14:56, Cambodia, 2458 content length.
# Page 60: 09 May 2023, 12:00, Indonesia, 1336 content length.
#
# Page 60 scraped. Total pages scraped so far: 60. Average time per page: 2.62 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=61
# Page 61: 06 May 2023, 18:00, , 1460 content length.
# Page 61: 06 May 2023, 18:00, , 3153 content length.
# Page 61: 05 May 2023, 18:00, Cambodia, 926 content length.
# Page 61: 05 May 2023, 12:46, Japan, 1013 content length.
# Page 61: 03 May 2023, 11:36, , 833 content length.
#
# Page 61 scraped. Total pages scraped so far: 61. Average time per page: 2.62 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=62
# Page 62: 02 May 2023, 17:32, Australia, 35752 content length.
# Page 62: 01 May 2023, 19:17, Australia, 24608 content length.
# Page 62: 01 May 2023, 16:30, Australia, 37268 content length.
# Page 62: 30 Apr 2023, 18:00, Australia, 984 content length.
# Page 62: 26 Apr 2023, 16:13, , 1555 content length.
#
# Page 62 scraped. Total pages scraped so far: 62. Average time per page: 2.62 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=63
# Page 63: 25 Apr 2023, 18:18, China, 4592 content length.
# Page 63: 25 Apr 2023, 17:27, Australia, Gabon, Uruguay, 4290 content length.
# Page 63: 23 Apr 2023, 10:57, Cuba, 2021 content length.
# Page 63: 23 Apr 2023, 09:08, , 963 content length.
# Page 63: 22 Apr 2023, 15:33, Malaysia, 1382 content length.
#
# Page 63 scraped. Total pages scraped so far: 63. Average time per page: 2.62 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=64
# Page 64: 21 Apr 2023, 18:00, Myanmar, 1234 content length.
# Page 64: 20 Apr 2023, 14:42, , 1089 content length.
# Page 64: 20 Apr 2023, 09:38, Cuba, 484 content length.
# Page 64: 19 Apr 2023, 13:00, China, 6866 content length.
# Page 64: 19 Apr 2023, 12:28, Brazil, 3268 content length.
#
# Page 64 scraped. Total pages scraped so far: 64. Average time per page: 2.62 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=65
# Page 65: 19 Apr 2023, 09:22, , 722 content length.
# Page 65: 18 Apr 2023, 13:27, Brazil, 8112 content length.
# Page 65: 16 Apr 2023, 18:10, Brazil, 882 content length.
# Page 65: 15 Apr 2023, 12:08, Malaysia, 1010 content length.
# Page 65: 04 Apr 2023, 19:39, , 2065 content length.
#
# Page 65 scraped. Total pages scraped so far: 65. Average time per page: 2.62 seconds.
#
# Scraping URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page
L: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos?keyword=&country=&startdate=01/01/2021&enddate=08/05/2024&topic=F5B66A618AEB4477A3E97996C9D05255&page=176
# No more statements found. Exiting...
#
# Scraping completed. 175 pages scraped in 457.89 seconds.
#
# 875 statements collected.

# %%
import json

# Save the scraped data into a JSON file
# with open('mfa_statements.json', 'w') as file:
#     json.dump(data, file, indent=4)

with open('mfa_statements.json', 'r') as file:
    data = json.load(file)

print(len(data), "statements saved and loaded.")
docs = data
# Out:
# 875 statements saved and loaded.

# %% [markdown]
# # Chunking
# I would like to chunk the documents so that the most relevant parts of the document can be shown to the chatbot, however, I would also like to know which document the chunk is from, so that I can reference it later.

# %%
# Convert the 'date' column to datetime first

# Adjust the date parsing to handle different date formats
for doc in docs:
    try:
        # Attempt to parse the date string into a datetime object using the expected format
        date_time_obj = datetime.datetime.strptime(doc['date'], '%d %b %Y, %H:%M')
    except ValueError:
        # If the first format fails, try parsing with an alternative format
        date_time_obj = datetime.datetime.fromisoformat(doc['date'])

    # Convert the datetime object to a string in ISO 8601 format as required by Elasticsearch
    doc['date'] = date_time_obj.isoformat()

df = pd.DataFrame(docs)

metadata = []
content = []
import random

# Iterate over the DataFrame to gather content and metadata
for index, row in df.iterrows():
    # Add the document content to the content list
    content.append(row['content'])

    # Create a metadata dictionary for this document, including the new fields
    meta = {
        "id": random.randint(1000, 9999),  # Generate a random ID for each document
        "url": row['url'],
        "title": row['title'],
        "date": row['date'],
        "country": row['country'],
    }

    # Add the metadata dictionary to the metadata list
    metadata.append(meta)

# Initialize the text splitter with desired chunk size and overlap
text_splitter = RecursiveCharacterTextSplitter(chunk_size=512, chunk_overlap=256)

# Create chunks (passages) with associated metadata
docs = text_splitter.create_documents(content, metadatas=metadata)

print(f"Split {len(df)} documents into {len(docs)} passages")
# Out:
# Split 875 documents into 8947 passages

# %%
import pickle

with open('mfa_chunks.pkl', 'wb') as outp:  # 'wb' for writing in binary mode
    pickle.dump(docs, outp, pickle.HIGHEST_PROTOCOL)

# %%
# Open the file in binary read mode ('rb') and load its contents into the variable `docs`
with open('mfa_chunks.pkl', 'rb') as inp:
    docs = pickle.load(inp)
docs[0].page_content
# Out:
# 'QUESTION Dr Wan RizalTo ask the Minister for Foreign Affairs whether the Ministry can provide an update on the measures currently in place to ensure the safety of Singaporeans residing in or travelling to the Middle East, particularly students, in light of recent military actions reported between Israel and Iran. REPLY 1 The question was addressed in MFA’s reply to a similar Question No. 5968 in Notice Paper No. 2733 of 2024, submitted by Member Zhulkarnain Abdul Rahim for the parliamentary sitting on 7 May'

# %%
# Prepare to load into Elasticsearch
final_docs = []
for doc in docs:
  meta = dict(doc.metadata)
  final_docs.append({
    "title": meta['title'],
    "url": meta['url'],
    "date": meta['date'],
    "country": meta['country'],
    "content": doc.page_content
  })

# Delete the original 'docs' list to free up memory
del docs

# %% [markdown]
# ## Load into Elasticsearch
# We used docker, enabled the security configuration which was quite **painful** to work with, but it would ensure that documents are secure.

# %%
# Connect to client (make sure Elasticsearch is running and listening on the specified address)
client = Elasticsearch("https://localhost:9200/",
                       basic_auth=("elastic", "*Td3NjQLaQPQQ*OYc5ES")) #yes the password is here, but its useless to you since its a locally hosted elasticsearch instance
try:
    client.indices.delete(index='article')
except:
    pass

# %%
with open('mfa_chunks_es.json', 'w') as file:
  save_to_json = json.dumps(final_docs)
  file.write(save_to_json)

# %%
with open('mfa_chunks_es.json', 'r') as file:
  final_docs = json.load(file)
print(final_docs[-1]['title'])
# Out:
# Condolences from Singapore Leaders on the Crash of Sriwijaya Air Flight SJ182

# %%
# Map the index's columns
index_name = "article"
index_mappings = {
  "mappings": {
    "properties": {
      "date": {"type": "date"},
      "title": {"type": "text"},
      "url": {"type": "text"},
      "country": {"type": "text"},
      "content": {"type": "text"},
    }
  }
}

if not client.indices.exists(index=index_name):
    client.indices.create(index=index_name, body=index_mappings)


actions = [
    {
        "_index": index_name,
        "_source": {
            "title": doc['title'],
            "url": doc['url'],
            "date": doc['date'],
            "country": doc['country'],
            "content": doc['content']
        }
    } for doc in final_docs
]

# Use the helpers.bulk() to add the documents to the index
resp = helpers.bulk(client, actions)
print(f"""Before: {client.count(index=index_name)['count']} documents 
Added: +{resp[0]} documents
Now: {int(resp[0])+int(client.count(index=index_name)['count'])} documents.""")
# its not accurate. make a GET request to ES /index/_search and check the hits.total.value
# Out:
# Before: 4473 documents
# Added: +8947 documents
# Now: 13420 documents.

# %% [markdown]
# ## Testing Elasticsearch & Abstraction
#
# Searching this way, Elasticsearch uses the BM25 algorithm by default, which is a extension of the TF-IDF algorithm with improvements that better handle the variation on document length and saturation of term frequency.
#
# If you just want to ingest data, this is the end. The rest is just playing around with retrieving data.

# %%
def es_search(client, search_body):
    pretty_result = ""

    # Perform the search query
    response = client.search(index="article", body=search_body)

    # Extract the relevant information
    hits = response['hits']['hits']
    total_hits = response['hits']['total']['value']

    # Build a readable result string
    pretty_result += f"Total documents found: {total_hits}\n"
    for i, hit in enumerate(hits, start=1):
        source = hit['_source']
        pretty_result += (
            f"Document {i}:\n"
            f"  Title: {source['title']}\n"
            f"  Date: {source['date']}\n"
            f"  URL: {source['url']}\n"
            f"  Country: {source['country']}\n"
            f"  Content: {source['content']}\n\n"  # Truncate content for display
        )

    return pretty_result.strip()

# %%
# search based on date fields
print(es_search(client, {
    "query": {
      "range": {
        "date": {
            "gte": "2024-03-03T00:00:00",  # March 3rd, 2024
            "lte": "2024-03-05T23:59:59"   # March 5th, 2024
            }}}}))
# Out:
# Total documents found: 71
# Document 1:
#   Title: 9th Singapore-Australia Annual Leaders' Meeting, 5 March 2024
#   Date: 2024-03-05T10:13:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/03/20240305-9th-SA-ALM
#   Country: Australia
#   Content: Prime Minister Lee Hsien Loong and Australian Prime Minister Anthony Albanese held the 9th Singapore-Australia Annual Leaders’ Meeting in Melbourne today. The Prime Ministers held a Joint Press Conference after their Meeting.
#
# Document 2:
#   Title: 9th Singapore-Australia Annual Leaders' Meeting, 5 March 2024
#   Date: 2024-03-05T10:13:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/03/20240305-9th-SA-ALM
#   Country: Australia
#   Content: The Prime Ministers reaffirmed the excellent state of bilateral relations and noted the good progress in bilateral cooperation across all six pillars of the Singapore-Australia Comprehensive Strategic Partnership (CSP), namely Economics and Trade, Defence and Foreign Affairs, Science and Innovation, People-to-People, Digital Economy and Green Economy.
#
# Document 3:
#   Title: 9th Singapore-Australia Annual Leaders' Meeting, 5 March 2024
#   Date: 2024-03-05T10:13:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/03/20240305-9th-SA-ALM
#   Country: Australia
#   Content: The Prime Ministers welcomed the deepening of bilateral cooperation in pathfinding areas such as the digital and green economies. They noted the good progress in implementing the Singapore-Australia Green Economy Agreement (SAGEA) since it was signed in October 2022, including the announcement of initial recipients of the A$20 million Go-Green Co-Innovation Programme grant which supports Singapore and Australian enterprises in collaborative efforts to innovate products and services in green sectors. The
#
# Document 4:
#   Title: 9th Singapore-Australia Annual Leaders' Meeting, 5 March 2024
#   Date: 2024-03-05T10:13:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/03/20240305-9th-SA-ALM
#   Country: Australia
#   Content: October 2022, including the announcement of initial recipients of the A$20 million Go-Green Co-Innovation Programme grant which supports Singapore and Australian enterprises in collaborative efforts to innovate products and services in green sectors. The Prime Ministers welcomed the signing of a Green and Digital Shipping Corridor Memorandum of Understanding to accelerate maritime decarbonisation and digitalisation, as well as a set of principles that both sides have jointly developed to guide cross-border
#
# Document 5:
#   Title: 9th Singapore-Australia Annual Leaders' Meeting, 5 March 2024
#   Date: 2024-03-05T10:13:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/03/20240305-9th-SA-ALM
#   Country: Australia
#   Content: Ministers welcomed the signing of a Green and Digital Shipping Corridor Memorandum of Understanding to accelerate maritime decarbonisation and digitalisation, as well as a set of principles that both sides have jointly developed to guide cross-border electricity trade for the region. The Prime Ministers also welcomed the finalisation of a Collaborative Instrument to further existing cooperation between our border agencies to combat cross-border criminal conduct.
#
# Document 6:
#   Title: 9th Singapore-Australia Annual Leaders' Meeting, 5 March 2024
#   Date: 2024-03-05T10:13:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/03/20240305-9th-SA-ALM
#   Country: Australia
#   Content: Ahead of the 10th anniversary of the CSP and the 60th anniversary of diplomatic relations in 2025, both Prime Ministers agreed to use the milestone to explore ambitious, forward-looking, and strategic areas of cooperation for the next phase of the CSP. They tasked Ministers and officials to develop a workplan of concrete initiatives by the Annual Leaders’ Meeting in 2025.
#
# Document 7:
#   Title: 9th Singapore-Australia Annual Leaders' Meeting, 5 March 2024
#   Date: 2024-03-05T10:13:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/03/20240305-9th-SA-ALM
#   Country: Australia
#   Content: The Prime Ministers also exchanged views on key regional and international developments. They agreed on the importance of an open and inclusive rules-based multilateral order, and underscored the importance of ASEAN Centrality. Prime Minister Lee welcomed Prime Minister Albanese’s commitment to deepen Australia’s engagement of Southeast Asia, including through initiatives such as Australia’s Southeast Asia Economic Strategy to 2040, and looked forward to the ASEAN-Australia Special Summit in Melbourne in
#
# Document 8:
#   Title: 9th Singapore-Australia Annual Leaders' Meeting, 5 March 2024
#   Date: 2024-03-05T10:13:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/03/20240305-9th-SA-ALM
#   Country: Australia
#   Content: Prime Minister Albanese’s commitment to deepen Australia’s engagement of Southeast Asia, including through initiatives such as Australia’s Southeast Asia Economic Strategy to 2040, and looked forward to the ASEAN-Australia Special Summit in Melbourne in commemoration of the Golden Jubilee of ASEAN-Australia Dialogue Relations.
#
# Document 9:
#   Title: 9th Singapore-Australia Annual Leaders' Meeting, 5 March 2024
#   Date: 2024-03-05T10:13:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/03/20240305-9th-SA-ALM
#   Country: Australia
#   Content: Following the Annual Leaders’ Meeting, the Prime Ministers issued a Joint Statement on the key outcomes. The full text of the Joint Statement is appended.
# MINISTRY OF FOREIGN AFFAIRS
# SINGAPORE
# 5 MARCH 2024
# Joint Statement for the 9th Singapore-Australia Annual Leaders’ Meeting
# The Prime Minister of Singapore, His Excellency Lee Hsien Loong, and the Prime Minister of Australia, the Hon Anthony Albanese MP, met for the 9th Singapore-Australia Annual Leaders’ Meeting in Melbourne on 5 March 2024.
#
# Document 10:
#   Title: 9th Singapore-Australia Annual Leaders' Meeting, 5 March 2024
#   Date: 2024-03-05T10:13:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/03/20240305-9th-SA-ALM
#   Country: Australia
#   Content: The Prime Minister of Singapore, His Excellency Lee Hsien Loong, and the Prime Minister of Australia, the Hon Anthony Albanese MP, met for the 9th Singapore-Australia Annual Leaders’ Meeting in Melbourne on 5 March 2024.
# Prime Minister Albanese was pleased to welcome Prime Minister Lee to Melbourne for the ASEAN-Australia Special Summit. The Leaders agreed on the importance of working closely with partners in Southeast Asia to ensure the region remains stable, peaceful and prosperous.

# %%
# search based on content fields
print(es_search(client, {
    "query": {
      "match": {
        "content": "Covid 19"}}}))
# Out:
# Total documents found: 624
# Document 1:
#   Title: Minister for Foreign Affairs Dr Vivian Balakrishn
00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2023/12/DPM-Wong-Special-Lecture_231213
#   Country:
#   Content: a. We ensured that trade, especially of medically critical products, continued to flow unimpeded between our two countries.
# b. We helped each other optimise our respective Covid-19 vaccination schedules, by coordinating a mutually beneficial vaccine-swap of Moderna vaccines.
# c. When Singapore decided to open up our borders and allow fully vaccinated travellers to enter Singapore without quarantine (i.e., Vaccinated Travel Lanes), Brunei was one of the first countries we opened up to.

# %%
# search using multi-match queries
# must be from SG, must not be from MY, should match phrase "Covid-19 vaccination"
print(es_search(client, {
    "query": {
        "bool": {
            "must": [
                {"match":{
                    "country": "Singapore"}}],
            "must_not": [
                {"match":{
                    "country": "Malaysia"}}],
            "should": [
                {"match_phrase": {
                    "content": "Covid-19 vaccination"}}]
            }}}))
# Out:
# Total documents found: 141
# Document 1:
#   Title: Minister for Foreign Affairs Dr Vivian Balakrishnan's Written Reply to Parliamentary Question on COVID-19 Vaccination rates of Singaporean students studying abroad and efforts to ensure their safety, 3 November 2021
#   Date: 2021-11-03T21:54:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2021/11/20211103-PQ
#   Country: Singapore
#   Content: QUESTION
# Dr Wan Rizal To ask the Minister for Foreign Affairs (a) what are the COVID-19 vaccination rates of Singaporean students studying abroad; and (b) what are the current efforts in ensuring the safety of our students overseas in a COVID-19 world.
# REPLY
# On part (a) of the query, we do not have statistics on the COVID-19 vaccination rates of Singaporean students who are based abroad.
#
# Document 2:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: Dawn Tan (CNA): The Israel-Hamas conflict featured very strongly in Parliament today. What would you say to those who perhaps are still unconvinced about Singapore’s neutrality in this matter?
# Minister Vivian Balakrishnan: The first thing I would say is that the real question is not neutrality. The real question is, “What is in Singapore’s national interest?”. We had an extensive discussion in Parliament today, and I would say the following.
#
# Document 3:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: First, because we are at risk, we have to call out terrorism – wherever, whenever, whatever pretext, whatever justification, whatever circumstance – we have to call it out. And we did. What happened on 7 October 2023 was a blatant and flagrant act of terror. As I said, we called it out for our own sakes because we are at risk. Second, if Singapore was ever attacked, we too would assert the right of self defence. Therefore, when we said Israel has the right, it was also with a view on what we would do or
#
# Document 4:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: As I said, we called it out for our own sakes because we are at risk. Second, if Singapore was ever attacked, we too would assert the right of self defence. Therefore, when we said Israel has the right, it was also with a view on what we would do or have to do if we were ever faced with such a situation. Third point is, we also have been reminding everyone, and in particular the Israelis, that anyone who exercises that right of self defence has to comply with international law, the Geneva Convention,
#
# Document 5:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: have to do if we were ever faced with such a situation. Third point is, we also have been reminding everyone, and in particular the Israelis, that anyone who exercises that right of self defence has to comply with international law, the Geneva Convention, international humanitarian law. That is why today, I stated for the record that in our view, Israel’s military response has now gone too far. These are statements that reflect Singapore’s position and Singapore’s national interest. It is not about
#
# Document 6:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: international humanitarian law. That is why today, I stated for the record that in our view, Israel’s military response has now gone too far. These are statements that reflect Singapore’s position and Singapore’s national interest. It is not about neutrality or balance. It is about what is in our own interest.
#
# Document 7:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: The other very important dimension I was trying to put across today is that we are, by definition, multi-racial, multi-lingual, multi-religious. Diversity is hard coded in our DNA. It is a design feature, it is a strength, but it is also a vulnerability. I was using our reactions to the conflict in Gaza as a worked example to tell all Singaporeans that there is going to be a wide diversity of views – some strongly held, some less so. The key challenge for us as Singaporeans is to respect each other, affirm
#
# Document 8:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: was using our reactions to the conflict in Gaza as a worked example to tell all Singaporeans that there is going to be a wide diversity of views – some strongly held, some less so. The key challenge for us as Singaporeans is to respect each other, affirm and recognise that we can have such strongly held views, but do not import foreign quarrels and do not let that divide and polarise us.
#
# Document 9:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: I was very cheered today that in Parliament, MPs, not just from the PAP (People’s Action Party), but from the Workers’ Party and including nominated MPs – we all arrived at a consensus. I hope that also will help engender a consensus in the larger Singapore community. Not an identity of views or perspectives, but that we can live with each other peacefully, and show the world how to live with such diversity. That will be Singapore's contribution to a world which has quite frankly become far more dangerous.
#
# Document 10:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: Otelli Edwards (CNA): We have seen and we have reported tens of thousands of lives lost because of the conflict, and you have also announced a third tranche of aid. Can you just give us a bit more details if it is going to be similar to previous tranches?

# %% [markdown]
# # Another layer of abstraction for our LLM
# Using the base of the multi-query, we open up possibilities to abstract our query making. This is important, so as to avoid any sort of syntax error created by our model.

# %%
def ESrch(client, must_query=None, must_not_query=None, should_query=None):
    bool_query = {}
    if must_query:
        bool_query["must"] = must_query if isinstance(must_query, list) else [must_query]
    if must_not_query:
        bool_query["must_not"] = must_not_query if isinstance(must_not_query, list) else [must_not_query]
    if should_query:
        bool_query["should"] = should_query if isinstance(should_query, list) else [should_query]
    response = client.search(index="article", body={"query": {"bool": {k: v for k, v in bool_query.items() if v}}})
    hits = response['hits']['hits']
    pretty_result = "\n".join([
        f"Total documents found: {response['hits']['total']['value']}"] + [
        f"Document {i+1}:\n  Title: {hit['_source'].get('title', 'N/A')}\n  Date: {hit['_source'].get('date', 'N/A')}\n  URL: {hit['_source'].get('url', 'N/A')}\n  Country: {hit['_source'].get('country', 'N/A')}\n  Content: {hit['_source'].get('content', 'N/A')}\n"
        for i, hit in enumerate(hits)])
    result_hits = [hit['_source'] for hit in hits]
    return result_hits, pretty_result

# %%
# search for date fields
must = {"range": {"date": {"gte": "2024-03-03T00:00:00"}}} # mandatory positive result
must_not = None # mandatory negative result
should = None # boosts the matched result
hits, result = ESrch(client, must)
print(result)
# Out:
# Total documents found: 669
# Document 1:
#   Title: Minister for Foreign Affairs Dr Vivian Balakrishnan's Written Reply to Parliamentary Question on Whether the Ministry Can Provide an Update on the Measures Currently in Place to Ensure the Safety of Singaporeans Residing in or Travelling to the Middle East, Particularly Students, in Light of Recent Military Actions Reported between Israel and Iran, 8 May 2024
#   Date: 2024-05-08T23:15:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/05/20240508-Written-PQ-on-Safety-of-Singaporeans-in-ME
#   Country:
#   Content: QUESTION Dr Wan RizalTo ask the Minister for Foreign Affairs whether the Ministry can provide an update on the measures currently in place to ensure the safety of Singaporeans residing in or travelling to the Middle East, particularly students, in light of recent military actions reported between Israel and Iran. REPLY 1 The question was addressed in MFA’s reply to a similar Question No. 5968 in Notice Paper No. 2733 of 2024, submitted by Member Zhulkarnain Abdul Rahim for the parliamentary sitting on 7 May
#
# Document 2:
#   Title: Minister for Foreign Affairs Dr Vivian Balakrishnan's Written Reply to Parliamentary Question on Whether the Ministry Can Provide an Update on the Measures Currently in Place to Ensure the Safety of Singaporeans Residing in or Travelling to the Middle East, Particularly Students, in Light of Recent Military Actions Reported between Israel and Iran, 8 May 2024
#   Date: 2024-05-08T23:15:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/05/20240508-Written-PQ

#   Title: Minister for Foreign Affairs Dr Vivian Balakrishnan's Written Reply to Parliamentary Question on the Steps That the Ministry Will Take, Given the Escalation of Conflict in the Middle East between Iran and Israel, to Reach Out to Singaporeans Studying or Working in the Region, Particularly Those in Neighbouring Countries Like Jordan and Egypt, to Check in on Their Safety and to Ensure Their Familiarity with Evacuation Plans Out of the Region In Case of Emergency, 8 May 2024
#   Date: 2024-05-08T23:02:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/05/20240508-Written-PQ-Singaporeans-in-ME
#   Country:
#   Content: Singaporean communities. MFA also has been working with the Islamic Religious Council of Singapore (Muis) and its Student Liaison Officers (SLOs) in Cairo and Jeddah to maintain contact with Singapore students pursuing religious studies in the region. This enables us to reach out and provide consular assistance quickly in any emergency. 4 Singaporeans in the Middle East should remain vigilant and monitor developments closely. They should also take all necessary precautions for their personal safety,
#
# Document 8:
#   Title: Minister for Foreign Affairs Dr Vivian Balakrishnan's Written Reply to Parliamentary Question on the Steps That the Ministry Will Take, Given the Escalation of Conflict in the Middle East between Iran and Israel, to Reach Out to Singaporeans Studying or Working in the Region, Particularly Those in Neighbouring Countries Like Jordan and Egypt, to Check in on Their Safety and to Ensure Their Familiarity with Evacuation Plans Out of the Region In Case of Emergency, 8 May 2024
#   Date: 2024-05-08T23:02:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/05/20240508-Written-PQ-Singaporeans-in-ME
#   Country:
#   Content: This enables us to reach out and provide consular assistance quickly in any emergency. 4 Singaporeans in the Middle East should remain vigilant and monitor developments closely. They should also take all necessary precautions for their personal safety, purchase comprehensive travel insurance, and eRegister with MFA. As Singapore does not have resident diplomatic missions in all countries in the region, Singaporeans may also wish to familiarise themselves with the locations of the nearest Singapore
#
# Document 9:
#   Title: Minister for Foreign Affairs Dr Vivian Balakrishnan's Written Reply to Parliamentary Question on the Steps That the Ministry Will Take, Given the Escalation of Conflict in the Middle East between Iran and Israel, to Reach Out to Singaporeans Studying or Working in the Region, Particularly Those in Neighbouring Countries Like Jordan and Egypt, to Check in on Their Safety and to Ensure Their Familiarity with Evacuation Plans Out of the Region In Case of Emergency, 8 May 2024
#   Date: 2024-05-08T23:02:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/05/20240508-Written-PQ-Singaporeans-in-ME
#   Country:
#   Content: purchase comprehensive travel insurance, and eRegister with MFA. As Singapore does not have resident diplomatic missions in all countries in the region, Singaporeans may also wish to familiarise themselves with the locations of the nearest Singapore Missions.
#
# Document 10:
#   Title: Minister for Foreign Affairs Dr Vivian Balakrishnan's Written Reply to Parliamentary Question on the Steps That the Ministry Will Take, Given the Escalation of Conflict in the Middle East between Iran and Israel, to Reach Out to Singaporeans Studying or Working in the Region, Particularly Those in Neighbouring Countries Like Jordan and Egypt, to Check in on Their Safety and to Ensure Their Familiarity with Evacuation Plans Out of the Region In Case of Emergency, 8 May 2024
#   Date: 2024-05-08T23:02:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/05/20240508-Written-PQ-Singaporeans-in-ME
#   Country:
#   Content: MINISTRY OF FOREIGN AFFAIRS SINGAPORE 8 MAY 2024

# %%
# search using multi-match queries
must = [{"match": {"country": "Singapore"}}, {"range": {"date": {"gte": "2023-03-03T00:00:00"}}}]
must_not = {"match": {"country": "Malaysia"}}
should = {"match_phrase": {"content": "Covid-19 vaccination"}}
hits, results = ESrch(client,must,must_not,should)
print(results)
# Out:
# Total documents found: 112
# Document 1:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: Dawn Tan (CNA): The Israel-Hamas conflict featured very strongly in Parliament today. What would you say to those who perhaps are still unconvinced about Singapore’s neutrality in this matter?
# Minister Vivian Balakrishnan: The first thing I would say is that the real question is not neutrality. The real question is, “What is in Singapore’s national interest?”. We had an extensive discussion in Parliament today, and I would say the following.
#
# Document 2:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: First, because we are at risk, we have to call out terrorism – wherever, whenever, whatever pretext, whatever justification, whatever circumstance – we have to call it out. And we did. What happened on 7 October 2023 was a blatant and flagrant act of terror. As I said, we called it out for our own sakes because we are at risk. Second, if Singapore was ever attacked, we too would assert the right of self defence. Therefore, when we said Israel has the right, it was also with a view on what we would do or
#
# Document 3:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: As I said, we called it out for our own sakes because we are at risk. Second, if Singapore was ever attacked, we too would assert the right of self defence. Therefore, when we said Israel has the right, it was also with a view on what we would do or have to do if we were ever faced with such a situation. Third point is, we also have been reminding everyone, and in particular the Israelis, that anyone who exercises that right of self defence has to comply with international law, the Geneva Convention,
#
# Document 4:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: have to do if we were ever faced with such a situation. Third point is, we also have been reminding everyone, and in particular the Israelis, that anyone who exercises that right of self defence has to comply with international law, the Geneva Convention, international humanitarian law. That is why today, I stated for the record that in our view, Israel’s military response has now gone too far. These are statements that reflect Singapore’s position and Singapore’s national interest. It is not about
#
# Document 5:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: international humanitarian law. That is why today, I stated for the record that in our view, Israel’s military response has now gone too far. These are statements that reflect Singapore’s position and Singapore’s national interest. It is not about neutrality or balance. It is about what is in our own interest.
#
# Document 6:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: The other very important dimension I was trying to put across today is that we are, by definition, multi-racial, multi-lingual, multi-religious. Diversity is hard coded in our DNA. It is a design feature, it is a strength, but it is also a vulnerability. I was using our reactions to the conflict in Gaza as a worked example to tell all Singaporeans that there is going to be a wide diversity of views – some strongly held, some less so. The key challenge for us as Singaporeans is to respect each other, affirm
#
# Document 7:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: was using our reactions to the conflict in Gaza as a worked example to tell all Singaporeans that there is going to be a wide diversity of views – some strongly held, some less so. The key challenge for us as Singaporeans is to respect each other, affirm and recognise that we can have such strongly held views, but do not import foreign quarrels and do not let that divide and polarise us.
#
# Document 8:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: I was very cheered today that in Parliament, MPs, not just from the PAP (People’s Action Party), but from the Workers’ Party and including nominated MPs – we all arrived at a consensus. I hope that also will help engender a consensus in the larger Singapore community. Not an identity of views or perspectives, but that we can live with each other peacefully, and show the world how to live with such diversity. That will be Singapore's contribution to a world which has quite frankly become far more dangerous.
#
# Document 9:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: Otelli Edwards (CNA): We have seen and we have reported tens of thousands of lives lost because of the conflict, and you have also announced a third tranche of aid. Can you just give us a bit more details if it is going to be similar to previous tranches?
#
# Document 10:
#   Title: Transcript of Minister for Foreign Affairs Dr Vivian Balakrishnan's Live Interview on Channel NewsAsia's "Singapore Tonight", 29 February 2024
#   Date: 2024-03-01T00:40:00
#   URL: https://www.mfa.gov.sg/Newsroom/Press-Statements-Transcripts-and-Photos/2024/02/240229_Minister-COS-CNA-Interview
#   Country: Singapore
#   Content: Minister: This time, we intend to work with our friends in Jordan. I just spoke to the Jordanian Foreign Minister yesterday. We are particularly focused on food and on medical supplies, because based on my interactions with him and the information we have been receiving, that is the critical need. We will make more announcements in the next couple of days but we do want to help. This expresses, again, the Singapore spirit at its best. Rather than just get angry, let us get active. Let us do something
